# %% [markdown]
# # Chạy sinh dữ liệu SFT Z3 bằng Qwen2.5 trên Colab GPU
#
# Notebook này dành cho việc bạn đã tải toàn bộ thư mục `EXACT_2026` lên Colab (hoặc mount từ Google Drive) và muốn dùng chính GPU của Colab để sinh file `train_code.jsonl`.

# %%
# Bước 1: Di chuyển vào thư mục dự án của bạn (Thay đổi đường dẫn nếu bạn mount từ Google Drive)
# Ví dụ: %cd /content/drive/MyDrive/EXACT_2026
# %cd /content/EXACT_2026

# %%
# Bước 2: Cài đặt các thư viện cần thiết cho dự án
# !pip install -r requirements.txt
# !pip install accelerate bitsandbytes sentence-transformers langchain_chroma

# %%
# Bước 3: Chạy script sinh dữ liệu mà chúng ta đã viết sẵn
# Lưu ý: Hãy đảm bảo file config/setting.yaml đang để model_id: "Qwen/Qwen2.5-7B-Instruct"

# !python scripts/build_synthetic_dataset.py

# %% [markdown]
# Sau khi ô trên chạy xong 100% (mất khoảng vài tiếng tùy GPU T4 hay A100), file `data/sft_dataset/train_code.jsonl` sẽ được tạo ra thành công. Bạn có thể mang file này qua sổ tay Unsloth để bắt đầu Fine-tune!
